# %%
import numpy as np

# %%
# Broadcasting allows NumPy to perform operations on arrays
# with different shapes by virtually expanding dimensions
# so they match the larger array's shape.

# The dimensions have the same size.
# OR
# One of the dimensions has a size of 1.

# %%
array0 = np.array([[1, 2 ,3, 4], 
                   [5, 6, 7, 8]])
array1 = np.array([[1], [2], [3], [4]])
print(array0.shape)
print(array1.shape)

# 
print(array0 * array1)
# Out:
# (2, 4)
# (4, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       4 print(array0.shape)
#       5 print(array1.shape)
# ----> 6 print(array0 * array1)
#
# ValueError: operands could not be broadcast together with shapes (2,4) (4,1)

# %%
array0 = np.array([[1, 3],
                   [2, 4]])
array1 = np.array([[1],
                   [2]])
print(array0 * array1)
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# /var/folders/xb/_7yxk2wn5mv91q46_p6csm6m0000gn/T/ipykernel_48622/4059787159.py:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   array0 = np.array([[1, 3]
# /var/folders/xb/_7yxk2wn5mv91q46_p6csm6m0000gn/T/ipykernel_48622/4059787159.py:1: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   array0 = np.array([[1, 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 array0 = np.array([[1, 3]
#       2                    [2, 4]])
#       3 array1 = np.array([[1],
#       4                    [2]])
#       5 print(array0 * array1)
#
# TypeError: list indices must be integers or slices, not tuple
